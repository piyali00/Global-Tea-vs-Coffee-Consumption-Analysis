# %%
# import the library

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# import cvs files
df = pd.read_csv(r'C:\Users\PK\Downloads\tea_vs_coffee_global_final.csv')

# %%
# first five rows
pd.set_option('display.max_columns', None)
df.head()
# Out:
#       country continent  year  age  gender income_level drink_preference  \
# 0  Bangladesh      Asia  2015   56    Male          Low           Coffee
# 1  Bangladesh      Asia  2015   61   Other         High              Tea
# 2  Bangladesh      Asia  2015   59  Female          Low           Coffee
# 3  Bangladesh      Asia  2015   41   Other         High           Coffee
# 4  Bangladesh      Asia  2015   43   Other       Middle              Tea
#
#   favorite_drink drink_category  cups_per_day drink_temperature sugar_level  \
# 0          Mocha         Modern           2.3              Both      Medium
# 1     Oolong Tea    Traditional           1.3              Both         Low
# 2      Americano         Modern           3.2              Cold      Medium
# 3     Cappuccino         Modern           3.0              Cold      Medium
# 4      Green Tea    Traditional           1.9               Hot      Medium
#
#   milk_usage caffeine_preference  taste_score  bitterness  acidity  \
# ...

# %%
df.tail()
# Out:
#       country continent  year  age  gender income_level drink_preference  \
# 14995   Egypt    Africa  2024   50  Female         High           Coffee
# 14996   Egypt    Africa  2024   35  Female          Low              Tea
# 14997   Egypt    Africa  2024   39    Male          Low           Coffee
# 14998   Egypt    Africa  2024   45    Male       Middle              Tea
# 14999   Egypt    Africa  2024   51   Other       Middle           Coffee
#
#       favorite_drink drink_category  cups_per_day drink_temperature  \
# 14995      Americano         Modern           2.8               Hot
# 14996    Masala Chai    Traditional           3.1               Hot
# 14997     Flat White         Modern           4.0              Both
# 14998       Milk Tea    Traditional           2.3              Both
# 14999          Mocha         Modern           4.0               Hot
#
#       sugar_level milk_usage caffeine_preference  taste_score  bitterness  \
# ...

# %%
# shape of the dataset
df.shape
# Out:
# (15000, 34)

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'age', 'gender', 'income_level',
#        'drink_preference', 'favorite_drink', 'drink_category', 'cups_per_day',
#        'drink_temperature', 'sugar_level', 'milk_usage', 'caffeine_preference',
#        'taste_score', 'bitterness', 'acidity', 'aroma_score', 'monthly_spend',
#        'price_per_cup', 'home_vs_cafe_ratio', 'work_type', 'sleep_hours',
#        'stress_level', 'exercise_frequency', 'bmi', 'hydration_level',
#        'heart_rate', 'drink_reason', 'social_setting', 'time_of_day',
#        'loyalty_brand', 'experiment_new_drinks', 'satisfaction_level'],
#       dtype='str')

# %%
df.dtypes
# Out:
# country                      str
# continent                    str
# year                       int64
# age                        int64
# gender                       str
# income_level                 str
# drink_preference             str
# favorite_drink               str
# drink_category               str
# cups_per_day             float64
# drink_temperature            str
# sugar_level                  str
# milk_usage                   str
# caffeine_preference          str
# taste_score              float64
# bitterness               float64
# acidity                  float64
# aroma_score              float64
# monthly_spend            float64
# price_per_cup            float64
# home_vs_cafe_ratio       float64
# work_type                    str
# sleep_hours              float64
# stress_level               int64
# exercise_frequency           str
# bmi                      float64
# hydration_level            int64
# heart_rate                 int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   country                15000 non-null  str
#  1   continent              15000 non-null  str
#  2   year                   15000 non-null  int64
#  3   age                    15000 non-null  int64
#  4   gender                 15000 non-null  str
#  5   income_level           15000 non-null  str
#  6   drink_preference       15000 non-null  str
#  7   favorite_drink         15000 non-null  str
#  8   drink_category         15000 non-null  str
#  9   cups_per_day           15000 non-null  float64
#  10  drink_temperature      15000 non-null  str
#  11  sugar_level            15000 non-null  str
#  12  milk_usage             15000 non-null  str
#  13  caffeine_preference    15000 non-null  str
#  14  taste_score            15000 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# country                  0
# continent                0
# year                     0
# age                      0
# gender                   0
# income_level             0
# drink_preference         0
# favorite_drink           0
# drink_category           0
# cups_per_day             0
# drink_temperature        0
# sugar_level              0
# milk_usage               0
# caffeine_preference      0
# taste_score              0
# bitterness               0
# acidity                  0
# aroma_score              0
# monthly_spend            0
# price_per_cup            0
# home_vs_cafe_ratio       0
# work_type                0
# sleep_hours              0
# stress_level             0
# exercise_frequency       0
# bmi                      0
# hydration_level          0
# heart_rate               0
# drink_reason             0
# social_setting           0
# time_of_day              0
# loyalty_brand            0
# experiment_new_drinks    0
# satisfaction_level       0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                year           age  cups_per_day   taste_score    bitterness  \
# count  15000.000000  15000.000000  15000.000000  15000.000000  15000.000000
# mean    2019.500000     41.115933      2.510380      5.528420      5.507433
# std        2.872377     13.495386      0.993814      2.589166      2.600703
# min     2015.000000     18.000000      0.000000      1.000000      1.000000
# 25%     2017.000000     30.000000      1.800000      3.300000      3.300000
# 50%     2019.500000     41.000000      2.500000      5.500000      5.500000
# 75%     2022.000000     53.000000      3.200000      7.800000      7.800000
# max     2024.000000     64.000000      6.000000     10.000000     10.000000
#
#             acidity   aroma_score  monthly_spend  price_per_cup  \
# count  15000.000000  15000.000000   15000.000000   15000.000000
# mean       5.541207      5.501993      51.904985       5.469805
# std        2.593605      2.585103      27.426476       2.594899
# ...

# %%
df['drink_preference'].value_counts()
# Out:
# drink_preference
# Tea       7703
# Coffee    7297
# Name: count, dtype: int64

# %%
df['drink_preference'].value_counts(normalize = True)*100
# Out:
# drink_preference
# Tea       51.353333
# Coffee    48.646667
# Name: proportion, dtype: float64

# %%
df['drink_preference'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='drink_preference'>

# %%
df.groupby(['continent', 'drink_preference']).size()
# Out:
# continent  drink_preference
# Africa     Coffee               550
#            Tea                  450
# America    Coffee              1675
#            Tea                 1325
# Asia       Coffee              1754
#            Tea                 3246
# Europe     Coffee              2761
#            Tea                 2239
# Oceania    Coffee               557
#            Tea                  443
# dtype: int64

# %%
df[df['drink_preference'] == 'Tea']['continent'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Continent Distribution For Tea")
plt.ylabel('')
plt.show()

# %%
df[df['drink_preference'] == 'Coffee']['continent'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Continent Distribution For Coffee")
plt.ylabel('')
plt.show()

# %%
pd.crosstab(df['income_level', df['drink_preference'], normalize = 'index')*100
# Out:
# drink_preference     Coffee        Tea
# income_level
# High              48.565710  51.434290
# Low               48.167800  51.832200
# Middle            49.170993  50.829007

# %%
df.groupby('drink_preference')[['sleep_hours','stress_level','acidity']].mean()
# Out:
#                   sleep_hours  stress_level   acidity
# drink_preference
# Coffee               7.011840      5.000685  5.531958
# Tea                  6.998014      4.993769  5.549968

# %%
bins = [18, 30, 40, 50, 64]
labels = ['18 - 30', '30 - 40', '40 - 50', '50 - 64']
df['age_group'] = pd.cut(df['age'], bins = bins, labels = labels, right = False)

# %%
pd.crosstab(df['age_group'], df['drink_preference'], normalize = 'index')*100
# Out:
# drink_preference     Coffee        Tea
# age_group
# 18 - 30           48.401826  51.598174
# 30 - 40           49.427021  50.572979
# 40 - 50           47.987220  52.012780
# 50 - 64           48.704319  51.295681

# %%
pd.crosstab(df['age_group'], df['drink_preference']).plot(kind = 'bar')
# Out:
# <Axes: xlabel='age_group'>
